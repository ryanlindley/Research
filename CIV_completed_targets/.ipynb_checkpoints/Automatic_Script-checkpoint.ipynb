# %%
import auto_fitting as auto
import glob
import os
auto.plt.rcParams['figure.figsize'] = [11, 8]

# %%
filenames = glob.glob('/Users/ryanlindley/Research/CIV/*')
CIV_targets = []
for f in filenames:
    CIV_targets.append(f.replace('/Users/ryanlindley/Research/CIV/', ''))
    
print(CIV_targets)
# Out:
# ['LBQS-0107-0235', 'LBQS-0107-0232', 'RXJ2154.1-4414', '1ES1553+113', 'PG0003+158', 'J1127+1154', 'MRK817', 'SDSSJ092554.43+453544.4', 'SDSSJ085116.14+424328.8', 'RXSJ00508+3536', 'PG0953+414', 'SDSSJ085259.22+031320.6', '4C-05.38', 'TON236', 'FBS0150+396', 'IZW1', 'MRK-1044', 'PHL1598', 'Q0349-146', '2MASX-J16194054+2543233', 'LBQS-1435-0134', 'PG-1338+416', 'FIRST-J020930.7-043826', 'RBS2005', 'PG1048+342', 'Q2135-145', 'RBS144', 'PG1121+422', 'MRK352', 'SDSS-J141038.39+230447.1', 'VV2006-J095243.0+515121', 'PKS0552-640', 'MR2251-178', 'Q2251+155', 'QSO-B1124+271', 'QSO0045+3926', 'J230837.73-525848.5', 'PMNJ1103-2329', 'B0117-2837', 'PG1216+069', 'CSO-0873', 'SDSSJ133053.27+311930.5', 'Q1545+210', 'RXS-J00057-5007', 'TONS210', 'QSO-B1435-0645', 'NGC7714', 'RBS1666', 'QSO-B0952+457', 'SDSSJ123235.82+060310.0', '1H-2129-624', 'PG1011-040', 'RBS1892', 'SDSSJ161916.54+334238.4', '1ES1028+511', 'PG-1630+377', 'SDSSJ135712.61+170444.1', '3C48', 'VIIZW244', 'PG1001+291', 'VV2006-J125901.7+413055', 'HB89-0232-042', '3C066A', 'SDSSJ092909.79+464424.0', 'Q0850+440', 'IRAS-L06229-6434', 'Q1354+195', 'PG0804+761', 'NGC-7469', 'RXS-J23218-7026', 'IRAS-F04250-5718', 'IRAS-F22456-5125', 'J0321-1758', 'CTS487', 'PG1222+216', 'SDSSJ080908.13+461925.6', 'PG1116+215', 'PDS456', 'NGC-985', 'SDSS-J135726.27+043541.4', 'IRASF00040+4325', 'PG1352+183', 'HE0238-1904', 'SDSS-J100535.24+013445.7', 'NGC-5548', 'MRK1148', 'MRK1513', 'PHL2525', '6C-092828+554656', 'MRK876', '4C-06.41', 'PKS1302-102', 'RXS-J21388-3828', 'VV2006-J095240.2+515250', 'PG1115+407', 'SDSSJ134206.56+050523.8', '1H1613-097', 'NGC-4051', 'MRK421', 'MRK841', '3C263', 'ESO292-G24', 'PHL1811', 'PKS0405-123', 'UKS-0242-724', 'B0120-28', 'RBS2055', 'MRK106', 'TON580', 'HE0153-4520', 'PKS0637-752', 'QSO-B1215+303', 'HE0056-3622', '3C57', 'HE0439-5254', 'SDSS-J141309.14+092011.2', 'PMNJ2345-1555', 'SDSSJ094840.08+580039.1', 'HB89-0107-025-NED05', 'J0315-2143', 'RBS2000', 'J213553.19-531655.7', 'PG-1522+101', '4C25.01', 'ESO-141-55', 'HS1102+3441', 'NGC-3516', 'J1156P1745', 'NGC-3783', 'PG1126-041', 'RXSJ00437+3725', 'PG1626+554', 'SDSSJ100102.55+594414.3', 'J0246-0059', 'S50716+714', 'PG1049-005', 'HE0226-4110', 'PG1259+593', 'MRK1392', 'SBS1108+560', 'PG1424+240', 'QSO-B1411+4414', 'FBQSJ1010+3003', 'MRK290', 'PG0052+251', 'SDSSJ105945.23+144142.9', 'RXJ0028.1+3103', 'RXJ1230.8+0115', 'ICRF-J122011.8+020342', 'FAIRALL9', 'PKS2005-489', 'RXJ0439.6-5311', 'MARK509', 'SBS1122+594']

# %%
name = CIV_targets[99]
print(name)
# Out:
# MRK841

# %%
directory = '/Users/ryanlindley/Research/CIV/' + name
os.chdir(directory)
os.getcwd()
# Out:
# '/Users/ryanlindley/Research/CIV/MRK841'

# %%
wl1, f1, gamma1, elem, state = (1548.187, 0.19, 0.00324, 'C', 'IV')
wl2, f2, gamma2, elem, state = (1550.772, 0.0952, 0.00325, 'C', 'IV')

path = '/Users/ryanlindley/Research/CIV/' + name + '/CIV.bin3.linespec'
wl, fl, fe, ctn = auto.np.loadtxt(path).transpose()
lsf = auto.np.loadtxt('/Users/ryanlindley/Research/CIV.old_setup/CIV.lsf')

# %%
new_ctn = auto.find_continuum(name, wl, fl, fe, ctn, [True]*len(wl))

#ctn_flag = auto.mask_wl(wl, [1545, 1548.8, 1550, 1551.7])  # add custom ctn if needed 
#manual_ctn = auto.find_continuum(name, wl, fl, fe, ctn, ctn_flag)

# %%
#new_ctn = manual_ctn # only include when manual continuum us found

fn = fl / new_ctn
fne = fe / new_ctn

# %%
#chi, chi_mean = auto.find_chi(wl, fl, fe, new_ctn)
#auto.plot_chi_histogram(chi, chi_mean)

#flag_chi = auto.mask_wl(wl, [1546, 1546.7, 1548, 1551.2]) # mask out regions for better calculation of chi histogram

#new_chi, new_chi_mean = auto.find_chi(wl[flag_chi], fl[flag_chi], fe[flag_chi], new_ctn[flag_chi])
#auto.plot_chi_histogram(new_chi, new_chi_mean)

# %%
x0 = [13, 20.3, auto.Wave2V(1548, wl1)] + [13.5, 20.3, auto.Wave2V(1548.5, wl1)] + [13, 20.3, auto.Wave2V(1548.5, wl1)] + [13, 20.3, auto.Wave2V(1550.5, wl2)] + [13, 20.3, auto.Wave2V(1547.5, wl1)] #+ [13, 20.3, auto.Wave2V(1549, wl1)] + [13, 20.3, auto.Wave2V(1550.5, wl2)] + [13, 20.3, auto.Wave2V(1550.5, wl2)]+ [13, 20.3, auto.Wave2V(1551.5, wl2)] 
feat = [0, 0, 0, 2, 1] #which features used to model 0 - both, 1 - strong, 2 - weak
p0, cov, a, b, c = auto.leastsq(auto.fitting, x0, full_output=1, args=(feat, wl, wl1, wl2, f1, f2, gamma1, gamma2, lsf, fn, fne, [1547, 1553]))


p1 = [ 14.53965, 24.06391002, -71.09040917,  13.52129405, 137.31813447, -27.9473738,   13.90456244,  15.60159991, -24.45908188]
auto.plot_model(p1, feat, wl, fn, wl1, wl2, f1, f2, gamma1, gamma2, lsf, [1547, 1553]) #normally [1547, 1553]
print(p0)
# Out:
# [ 14.52409884  25.4789655  -71.70344927  12.83845965  22.20429671
#   42.31531395  12.81378429  20.44320541 150.59264877  13.98253946
#   21.37696459 -25.46373478  13.93607155  17.1596903  -24.41426304]

# %%
N1, N2 = auto.make_features(p0, feat, wl, wl1, wl2, lsf, gamma1, gamma2)
Ne1 = auto.nfle2Nev(fn, fne, f1, wl1)
Ne2 = auto.nfle2Nev(fn, fne, f2, wl2)
auto.plot_features(wl, wl1, wl2, N1, N2, Ne1, Ne2, [-300, 300])
print(p0)
# Out:
# [ 14.52409884  25.4789655  -71.70344927  12.83845965  22.20429671
#   42.31531395  12.81378429  20.44320541 150.59264877  13.98253946
#   21.37696459 -25.46373478  13.93607155  17.1596903  -24.41426304]

# %%
N1r, N2r = auto.add_residual(p0, N1, N2, feat, wl, wl1, wl2, f1, f2, gamma1, gamma2, lsf, fn)
auto.plot_features(wl, wl1, wl2, N1r, N2r, Ne1, Ne2, [-300, 300])

# %%
strong_flag = auto.mask_v(wl, wl1, []) # add masking for any regions not to be used in combined data
weak_flag = auto.mask_v(wl, wl2, [])
v1, v2, Nv1, Nv2, Nve1, Nve2 = auto.remove_regions(strong_flag, weak_flag, wl, wl1, wl2, N1r, N2r, Ne1, Ne2)

v_bins, Nv_bins, Nve_bins = auto.make_bins(v1, v2, Nv1, Nv2, Nve1, Nve2)

v_final, Nv_final, Nve_final =  auto.final_data(v_bins, Nv_bins, Nve_bins)

auto.plot_final_data(wl, wl1, wl2, N1r, N2r, v_final, Nv_final, Nve_final, name, [-300, 300])

# %%
#N = auto.find_N(-115, 110, v_final, Nv_final)
#print('Column Density: ', N)

# %%
data = auto.np.c_[v_final, Nv_final, Nve_final]
regions = [[-175, 80]]

auto.np.savetxt('CIV.data', data)
auto.np.savetxt('CIV.regions', regions, fmt='%1.3i')
auto.save_final_data_plot(wl, wl1, wl2, N1r, N2r, v_final, Nv_final, Nve_final, name, [-300, 300])
auto.save_final_continuum_data(wl, fl, new_ctn, name)
